# %% [markdown]
# ![image.png](attachment:926ae22e-a832-4c9d-ae93-f28461157069.png)

# %%
''' Class is a blueprint which defines some properties and behaviors. 
    An object is an instance of a class which has those properties and behaviours attached'''
class student:
    def __init__(self,name,roll_no,section):
        self.name=name
        self.roll_no=roll_no
        self.section=section
    def display(self):
        print(self.name,self.roll_no,self.section)
ravi=student('ravi',32323222,'A')
ravi.display()
# Out:
# ravi 32323222 A

# %% [markdown]
# ![image.png](attachment:4b15e6f5-2362-4c57-bc85-27c2c6d2a00a.png)

# %% [markdown]
# Four pillars of oops are:
# polymorphism
# inheritance
# abstraction
# encapsulation

# %% [markdown]
# ![image.png](attachment:768f45f8-6b0f-43d6-9103-bfea09b3088b.png)

# %%
# __init__() is used to passed the object parameters to the class
class student:
    def __init__(self,name,roll_no,section):
        self.name=name
        self.roll_no=roll_no
        self.section=section
    def display(self):
        print(self.name,self.roll_no,self.section)
ravi=student('ravi',32323222,'A')
ravi.display()
# Out:
# ravi 32323222 A

# %% [markdown]
# ![image.png](attachment:732681f7-e523-4499-afaf-ee74a1d4a01c.png)

# %% [markdown]
# The self parameter is a reference to the current instance of the class, and is used to access variables that belongs to the  class.
# It does not have to be named self , you can call it whatever you like, but it has to be the first parameter of any function in the class.

# %% [markdown]
# ![image.png](attachment:63c5832f-a18a-4b06-a22b-fcfde666407f.png)

# %%
# inheritance means that  child class inhirenting the properties of parent class 
# types of inheritance
# single inheritance
# multiple inheritance
# multilevel inheritance
# hirerical inheritance

# single inheritance
class parent:
    def __init__(self):
        print("i am a parent class")
p1=parent()
    
# multilevel
class parent:
    def __init__(self):
          print("i am a parent class")
class child(parent):
    def __init__(self):
        print(" i am child class")
class grandchildren(child):
    def __init__(self):
        print(" i am a granchild class")
    
gc=grandchildren()

# hirerical inheritance

class parent:
    def __init__(self):
          print("i am a parent class")
class child1(parent):
    def __init__(self):
        print(" i am child class")
class child2(parent):
     def __init__(self):
        print(" i am child class")

# multiple inheritance

class mother:
     def __init__(self):
        print("i am a mother class")
class father:
    def __init__(self):
        print("i am a mother class")
class child(mother,father):
     def __init__(self):
        print("i am a child class")
